# %% [markdown]
# # 2주차 Walkthrough
#
# Subagents와 Human-in-the-loop 데모 5종을 순서대로 실행한다.

# %%
# %run 01_basic_subagent.py

# %%
# %run 02_specialized_subagents.py

# %%
# %run 03_interrupt_approval.py

# %%
# %run 04_interrupt_edit.py

# %%
# %run 05_subagent_interrupt.py
